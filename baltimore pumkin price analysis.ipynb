# %%
import pandas as pd
import numpy as  np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
pumpkins = pd.read_csv(r'C:\Users\CHRIS\Downloads\datasets\pumpkinCSV\baltimore_9-24-2016_9-30-2017.csv')
pumpkins.head(10)
# Out:
#   Commodity Name  City Name  Type       Package      Variety Sub Variety  \
# 0       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 1       PUMPKINS  BALTIMORE   NaN  24 inch bins          NaN         NaN
# 2       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 3       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 4       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 5       PUMPKINS  BALTIMORE   NaN  24 inch bins  HOWDEN TYPE         NaN
# 6       PUMPKINS  BALTIMORE   NaN  36 inch bins  HOWDEN TYPE         NaN
# 7       PUMPKINS  BALTIMORE   NaN  36 inch bins  HOWDEN TYPE         NaN
# 8       PUMPKINS  BALTIMORE   NaN  36 inch bins  HOWDEN TYPE         NaN
# 9       PUMPKINS  BALTIMORE   NaN  36 inch bins  HOWDEN TYPE         NaN
#
#    Grade        Date  Low Price  High Price  ...  Color  Environment  \
# 0    NaN  04/29/2017        270       280.0  ...    NaN          NaN
# 1    NaN  05/06/2017        270       280.0  ...    NaN          NaN
# 2    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 3    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 4    NaN  11/05/2016         90       100.0  ...    NaN          NaN
# 5    NaN  11/12/2016         90       100.0  ...    NaN          NaN
# 6    NaN  09/24/2016        160       170.0  ...    NaN          NaN
# 7    NaN  09/24/2016        160       160.0  ...    NaN          NaN
# 8    NaN  10/01/2016        160       170.0  ...    NaN          NaN
# 9    NaN  10/01/2016        160       160.0  ...    NaN          NaN
#
#   Unit of Sale  Quality Condition Appearance  Storage Crop  Repack  Trans Mode
# 0          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 1          NaN      NaN       NaN        NaN      NaN  NaN       E         NaN
# 2          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 3          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 4          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 5          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 6          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 7          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 8          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
# 9          NaN      NaN       NaN        NaN      NaN  NaN       N         NaN
#
# [10 rows x 25 columns]

# %%
new_columns = ['Color','Origin','Item Size','Variety','City Name','Package']
new_pumpkins = pumpkins.drop([c for c in pumpkins.columns if c not in new_columns ],axis=1)
new_pumpkins.dropna(inplace=True)
new_pumpkins
# Out:
#      City Name               Package        Variety        Origin Item Size  \
# 23   BALTIMORE          36 inch bins    HOWDEN TYPE      MARYLAND   med-lge
# 24   BALTIMORE          36 inch bins    HOWDEN TYPE      MARYLAND   med-lge
# 25   BALTIMORE          36 inch bins    HOWDEN TYPE      MARYLAND       lge
# 26   BALTIMORE          36 inch bins    HOWDEN TYPE      MARYLAND   med-lge
# 87   BALTIMORE  1 1/9 bushel cartons       PIE TYPE      MARYLAND       med
# 88   BALTIMORE  1 1/9 bushel cartons       PIE TYPE      DELAWARE       med
# 89   BALTIMORE  1 1/9 bushel cartons       PIE TYPE      MARYLAND       med
# 90   BALTIMORE  1 1/9 bushel cartons       PIE TYPE  PENNSYLVANIA       med
# 91   BALTIMORE  1 1/9 bushel cartons       PIE TYPE      DELAWARE       med
# 92   BALTIMORE  1 1/9 bushel cartons       PIE TYPE  PENNSYLVANIA       med
# 94   BALTIMORE          24 inch bins       PIE TYPE      MARYLAND       sml
# 95   BALTIMORE          24 inch bins       PIE TYPE      MARYLAND       sml
# 105  BALTIMORE          24 inch bins  BIG MACK TYPE      MARYLAND       lge
# 106  BALTIMORE          24 inch bins  BIG MACK TYPE      MARYLAND       med
# 110  BALTIMORE          24 inch bins  BIG MACK TYPE      MARYLAND       lge
# 111  BALTIMORE          24 inch bins  BIG MACK TYPE      MARYLAND       med
# 114  BALTIMORE          24 inch bins  BIG MACK TYPE      MARYLAND       lge
# 124  BALTIMORE    1/2 bushel cartons      MINIATURE      MARYLAND       sml
# 126  BALTIMORE    1/2 bushel cartons      MINIATURE      MARYLAND       sml
# 128  BALTIMORE    1/2 bushel cartons      MINIATURE      MARYLAND       sml
# 133  BALTIMORE    1/2 bushel cartons      MINIATURE      MARYLAND       sml
# 137  BALTIMORE    1/2 bushel cartons      MINIATURE      MARYLAND       sml
# 141  BALTIMORE    1/2 bushel cartons      MINIATURE      MARYLAND       sml
#
#       Color
# 23   ORANGE
# 24   ORANGE
# 25   ORANGE
# 26   ORANGE
# 87   ORANGE
# 88   ORANGE
# 89   ORANGE
# 90   ORANGE
# 91   ORANGE
# 92   ORANGE
# 94   ORANGE
# 95   ORANGE
# 105   WHITE
# 106   WHITE
# 110   WHITE
# 111   WHITE
# 114   WHITE
# 124   WHITE
# 126   WHITE
# 128   WHITE
# 133   WHITE
# 137   WHITE
# 141   WHITE

# %%
from sklearn.preprocessing import LabelEncoder
new_columns = ['Color','Origin','Item Size','Variety','City Name','Package']
new_pumpkins = pumpkins.drop([c for c in pumpkins.columns if c not in new_columns ],axis=1)
new_pumpkins.dropna(inplace=True)
new_pumpkins = new_pumpkins.apply(LabelEncoder().fit_transform)
new_pumpkins
# Out:
#      City Name  Package  Variety  Origin  Item Size  Color
# 23           0        3        1       1          2      0
# 24           0        3        1       1          2      0
# 25           0        3        1       1          0      0
# 26           0        3        1       1          2      0
# 87           0        0        3       1          1      0
# 88           0        0        3       0          1      0
# 89           0        0        3       1          1      0
# 90           0        0        3       2          1      0
# 91           0        0        3       0          1      0
# 92           0        0        3       2          1      0
# 94           0        2        3       1          3      0
# 95           0        2        3       1          3      0
# 105          0        2        0       1          0      1
# 106          0        2        0       1          1      1
# 110          0        2        0       1          0      1
# 111          0        2        0       1          1      1
# 114          0        2        0       1          0      1
# 124          0        1        2       1          3      1
# 126          0        1        2       1          3      1
# 128          0        1        2       1          3      1
# 133          0        1        2       1          3      1
# 137          0        1        2       1          3      1
# 141          0        1        2       1          3      1

# %%
new_pumpkins.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 23 to 141
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   City Name  23 non-null     int32
#  1   Package    23 non-null     int32
#  2   Variety    23 non-null     int32
#  3   Origin     23 non-null     int32
#  4   Item Size  23 non-null     int32
#  5   Color      23 non-null     int32
# dtypes: int32(6)
# memory usage: 736.0 bytes

# %%
g = sns.PairGrid(new_pumpkins)

g.map(sns.scatterplot)

# %%
sns.swarmplot(x="Color", y="Item Size", data=new_pumpkins, )
# Out:
# <AxesSubplot:xlabel='Color', ylabel='Item Size'>

# %%
sns.catplot(x="Color", y="Item Size",
            kind="violin", data=new_pumpkins)

# %%
from sklearn. model_selection import train_test_split
Selected_features = ['Origin','Item Size','Variety','City Name','Package']
X = new_pumpkins[Selected_features]
y = new_pumpkins['Color']

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=2)

# %%
X_test
# Out:
#      Origin  Item Size  Variety  City Name  Package
# 133       1          3        2          0        1
# 23        1          2        1          0        3
# 137       1          3        2          0        1
# 89        1          1        3          0        0
# 110       1          0        0          0        2

# %%
from sklearn.metrics import accuracy_score, classification_report
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(X_train, y_train)
predictions = model.predict(X_test)
print (classification_report (y_test, predictions))
print('Predicted labels: ', predictions)
print('Accuracy: ', accuracy_score(y_test, predictions))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00         2
#            1       1.00      1.00      1.00         3
#
#     accuracy                           1.00         5
#    macro avg       1.00      1.00      1.00         5
# weighted avg       1.00      1.00      1.00         5
#
# Predicted labels:  [1 0 1 0 1]
# Accuracy:  1.0

# %%
print(predictions)
print (y_test)
# Out:
# [1 0 1 0 1]
# 133    1
# 23     0
# 137    1
# 89     0
# 110    1
# Name: Color, dtype: int32
