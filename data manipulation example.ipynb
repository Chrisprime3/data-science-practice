# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris

# %%
iris = load_iris()
df = pd.DataFrame(data=iris['data'], columns=iris['feature_names'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   sepal length (cm)  150 non-null    float64
#  1   sepal width (cm)   150 non-null    float64
#  2   petal length (cm)  150 non-null    float64
#  3   petal width (cm)   150 non-null    float64
# dtypes: float64(4)
# memory usage: 4.8 KB

# %%
df.describe()
df.shape
# Out:
# (150, 4)

# %%
df =pd.read_csv('')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Untitled-1.ipynb Cell 4 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#ch0000003untitled?line=0'>1</a> df =pd.read_csv('')
#
# File c:\Users\CHRIS\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %%
df.nunique
# Out:
# <bound method DataFrame.nunique of      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
# ...

# %%
import numpy as np
example1 =pd.DataFrame([[1,  np.nan,  7],
                       [2,     4,    8],
                       [np.nan,3,     nan]])
example1
# Out:
#      0    1  2
# 0  1.0  NaN  7
# 1  2.0  4.0  8
# 2  NaN  3.0  0

# %%
example1.dropna(axis='rows', thresh=0)
# Out:
#      0    1  2
# 0  1.0  NaN  7
# 1  2.0  4.0  8
# 2  NaN  3.0  0

# %%
df1 =pd.DataFrame({'employee':['Tim','Jerry','Prime','Rose'],
'group':['Field','works','accounting','sanitation']})
df1
# Out:
#   employee       group
# 0      Tim       Field
# 1    Jerry       works
# 2    Prime  accounting
# 3     Rose  sanitation

# %%
df = pd.read_csv(r'C:\Users\CHRIS\Downloads\datasets\HousingData.csv')
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  486.000000  486.000000  486.000000  486.000000  506.000000  506.000000
# mean     3.611874   11.211934   11.083992    0.069959    0.554695    6.284634
# std      8.720192   23.388876    6.835896    0.255340    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.081900    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.253715    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.560263   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  486.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.518519    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df['INDUS'].mean()
# Out:
# 11.083991769547325

# %%
df.groupby(['AGE'])['MEDV'].mean()
# Out:
# AGE
# 2.9      26.600000
# 6.2      23.400000
# 6.5      24.700000
# 6.6      24.750000
# 6.8      29.600000
#            ...
# 98.8     14.500000
# 98.9     13.066667
# 99.1     10.900000
# 99.3     17.800000
# 100.0    16.133333
# Name: MEDV, Length: 348, dtype: float64

# %%
df['AGE_50'] = df['AGE'].apply (lambda x: x>50)
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV  AGE_50
# 0  396.90   4.98  24.0    True
# 1  396.90   9.14  21.6    True
# 2  392.83   4.03  34.7    True
# 3  394.63   2.94  33.4   False
# 4  396.90    NaN  36.2    True

# %%
df.groupby(['AGE_50'])['CRIM']

# %%
df['AGE_50'].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0       True
# 1       True
# 2       True
# 3      False
# 4       True
#        ...
# 501     True
# 502     True
# 503     True
# 504     True
# 505    False
# Name: AGE_50, Length: 506, dtype: bool>

# %%
groupby_twovar = df.groupby(['AGE_50','CRIM','RAD'])['MEDV'].mean()
groupby_twovar
# Out:
# AGE_50  CRIM      RAD
# False   0.00906   1      32.2
#         0.01096   1      22.0
#         0.01301   1      32.7
#         0.01311   5      35.4
#         0.01360   3      18.9
#                          ...
# True    45.74610  24      7.0
#         51.13580  24     15.0
#         67.92080  24      5.0
#         73.53410  24      8.8
#         88.97620  24     10.4
# Name: MEDV, Length: 485, dtype: float64

# %%
groupby_twovar.unstack()
# Out:
# RAD                1   2     3   4     5   6   7   8     24
# AGE_50 CRIM
# False  0.00906   32.2 NaN   NaN NaN   NaN NaN NaN NaN   NaN
#        0.01096   22.0 NaN   NaN NaN   NaN NaN NaN NaN   NaN
#        0.01301   32.7 NaN   NaN NaN   NaN NaN NaN NaN   NaN
#        0.01311    NaN NaN   NaN NaN  35.4 NaN NaN NaN   NaN
#        0.01360    NaN NaN  18.9 NaN   NaN NaN NaN NaN   NaN
# ...               ...  ..   ...  ..   ...  ..  ..  ..   ...
# True   45.74610   NaN NaN   NaN NaN   NaN NaN NaN NaN   7.0
#        51.13580   NaN NaN   NaN NaN   NaN NaN NaN NaN  15.0
#        67.92080   NaN NaN   NaN NaN   NaN NaN NaN NaN   5.0
#        73.53410   NaN NaN   NaN NaN   NaN NaN NaN NaN   8.8
#        88.97620   NaN NaN   NaN NaN   NaN NaN NaN NaN  10.4
#
# [484 rows x 9 columns]

# %%
df['CHAS'].value_counts().plot(kind ='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
plt.hist(df['MEDV'],bins=50)
# Out:
# (array([ 3.,  1.,  7.,  7.,  3.,  6.,  8., 10.,  8., 23., 15., 19., 14.,
#         16., 18., 28., 36., 29., 33., 28., 37., 21., 15.,  4.,  7., 11.,
#          9.,  9.,  5.,  7.,  7.,  8.,  2.,  8.,  5.,  4.,  2.,  1.,  1.,
#          0.,  2.,  2.,  2.,  2.,  2.,  1.,  1.,  0.,  3., 16.]),
#  array([ 5. ,  5.9,  6.8,  7.7,  8.6,  9.5, 10.4, 11.3, 12.2, 13.1, 14. ,
#         14.9, 15.8, 16.7, 17.6, 18.5, 19.4, 20.3, 21.2, 22.1, 23. , 23.9,
#         24.8, 25.7, 26.6, 27.5, 28.4, 29.3, 30.2, 31.1, 32. , 32.9, 33.8,
#         34.7, 35.6, 36.5, 37.4, 38.3, 39.2, 40.1, 41. , 41.9, 42.8, 43.7,
#         44.6, 45.5, 46.4, 47.3, 48.2, 49.1, 50. ]),
#  <BarContainer object of 50 artists>)
